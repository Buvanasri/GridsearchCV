# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","sex_male","bmi","children","smoker_yes"]]

# %%
independent
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','absolute-error','friedman_mse','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]}
            
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'friedman_mse', 'squared_error', 'absolute_error'}. Got 'absolute-error' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'poisson', 'squared_error', 'friedman_mse'}. Got 'absolute-error' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.81241141 0.83256787 0.81473672 0.83278424
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.81066355 0.83204113 0.82007051 0.834129
#         nan        nan 0.81799029 0.83471995 0.82169703 0.83367175]
#   warnings.warn(
# C:\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute-error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for the best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for the best parameter{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004399      0.000490         0.000000        0.000000
# 1        0.006194      0.003917         0.000000        0.000000
# 2        0.142910      0.004334         0.013593        0.001743
# 3        1.711345      0.167554         0.048970        0.002096
# 4        0.138715      0.002481         0.013192        0.001164
# 5        1.793895      0.277309         0.095541        0.040803
# 6        0.003798      0.000748         0.000000        0.000000
# 7        0.003397      0.001019         0.000000        0.000000
# 8        0.005397      0.002243         0.000000        0.000000
# 9        0.003598      0.001356         0.000000        0.000000
# 10       0.003598      0.001019         0.000000        0.000000
# 11       0.002799      0.000400         0.000000        0.000000
# 12       0.003198      0.000400         0.000000        0.000000
# 13       0.002997      0.000001         0.000000        0.000000
# 14       0.180690      0.016835         0.017588        0.006998
# 15       2.064328      0.288932         0.049171        0.006819
# 16       0.261438      0.079557         0.026384        0.014573
# 17       1.866650      0.320842         0.048970        0.004601
# 18       0.005996      0.002897         0.000000        0.000000
# 19       0.003199      0.000748         0.000000        0.000000
# 20       0.179888      0.044403         0.013392        0.001959
# 21       2.006963      0.360601         0.067759        0.020011
# 22       0.208071      0.041425         0.014791        0.002992
# 23       1.821878      0.211711         0.066559        0.016513
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute-error               auto                 10
# 7   absolute-error               auto                100
# 8   absolute-error               sqrt                 10
# 9   absolute-error               sqrt                100
# 10  absolute-error               log2                 10
# 11  absolute-error               log2                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               sqrt                 10
# 15    friedman_mse               sqrt                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
# 18         poisson               auto                 10
# 19         poisson               auto                100
# 20         poisson               sqrt                 10
# 21         poisson               sqrt                100
# 22         poisson               log2                 10
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.845078
# 3   {'criterion': 'squared_error', 'max_features':...           0.855461
# 4   {'criterion': 'squared_error', 'max_features':...           0.844777
# 5   {'criterion': 'squared_error', 'max_features':...           0.858849
# 6   {'criterion': 'absolute-error', 'max_features'...                NaN
# 7   {'criterion': 'absolute-error', 'max_features'...                NaN
# 8   {'criterion': 'absolute-error', 'max_features'...                NaN
# 9   {'criterion': 'absolute-error', 'max_features'...                NaN
# 10  {'criterion': 'absolute-error', 'max_features'...                NaN
# 11  {'criterion': 'absolute-error', 'max_features'...                NaN
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.831427
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.855460
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.851682
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.859084
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.843633
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859008
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.841637
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.862167
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.759422           0.829587           0.807955
# 3            0.779894           0.863460           0.829235
# 4            0.756103           0.845242           0.806114
# 5            0.774285           0.864438           0.827446
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.758721           0.836799           0.802478
# 15           0.776847           0.862925           0.828461
# 16           0.765386           0.841364           0.807019
# 17           0.779623           0.861907           0.832408
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.775451           0.838859           0.807574
# 21           0.785332           0.862402           0.827491
# 22           0.763738           0.845880           0.818437
# 23           0.774923           0.860777           0.830333
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2            0.820015         0.812411        0.029147               11
# 3            0.834789         0.832568        0.029220                5
# 4            0.821448         0.814737        0.032834               10
# 5            0.838903         0.832784        0.032154                4
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8                 NaN              NaN             NaN               13
# 9                 NaN              NaN             NaN               13
# 10                NaN              NaN             NaN               13
# 11                NaN              NaN             NaN               13
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14           0.823892         0.810664        0.028475               12
# 15           0.836513         0.832041        0.030270                6
# 16           0.834901         0.820071        0.031091                8
# 17           0.837623         0.834129        0.029599                2
# 18                NaN              NaN             NaN               13
# 19                NaN              NaN             NaN               13
# 20           0.824435         0.817990        0.024709                9
# 21           0.839366         0.834720        0.027818                1
# 22           0.838793         0.821697        0.030478                7
# 23           0.840158         0.833672        0.031785                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age:45
# BMI:56
# Children:2
# sex male 0 or 1:1
# Smoker yes 0 or 1:2

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[23712.5545906]
# C:\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
