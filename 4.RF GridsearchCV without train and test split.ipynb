# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","sex_male","bmi","children","smoker_yes"]]

# %%
independent
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
independent=scx.fit_transform(independent)
scy=StandardScaler()
dependent=scy.fit_transform(dependent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features': ['sqrt','log2'],
              'n_estimators':[50,100]}
            
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 20 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 378, in fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.83215922 0.83221929 0.83338663 0.83381481 0.8306949  0.83345
#  0.8273194  0.83580554 0.83341746 0.83476137 0.83363222 0.83323179
#         nan        nan        nan        nan]
#   warnings.warn(
# C:\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}: 0.9711883680182786

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.637206      0.011105         0.022786        0.003707
# 1        1.206856      0.013207         0.037577        0.001019
# 2        0.610423      0.006270         0.020188        0.000400
# 3        1.198261      0.015405         0.036577        0.001853
# 4        1.737129      0.031492         0.020588        0.003260
# 5        3.509038      0.051222         0.037977        0.002606
# 6        1.741726      0.015680         0.018789        0.001720
# 7        3.770277      0.107033         0.051768        0.019040
# 8        0.680381      0.039515         0.021587        0.004221
# 9        1.304596      0.043582         0.040774        0.006671
# 10       0.616619      0.008848         0.020388        0.001355
# 11       1.191465      0.081813         0.034979        0.006352
# 12       0.004396      0.001854         0.000000        0.000000
# 13       0.004197      0.001469         0.000000        0.000000
# 14       0.005596      0.002060         0.000000        0.000000
# 15       0.011591      0.011423         0.000000        0.000000
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4   absolute_error               sqrt                 50
# 5   absolute_error               sqrt                100
# 6   absolute_error               log2                 50
# 7   absolute_error               log2                100
# 8     friedman_mse               sqrt                 50
# 9     friedman_mse               sqrt                100
# 10    friedman_mse               log2                 50
# 11    friedman_mse               log2                100
# 12         poisson               sqrt                 50
# 13         poisson               sqrt                100
# 14         poisson               log2                 50
# 15         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.859541
# 1   {'criterion': 'squared_error', 'max_features':...           0.860734
# 2   {'criterion': 'squared_error', 'max_features':...           0.855213
# 3   {'criterion': 'squared_error', 'max_features':...           0.857595
# 4   {'criterion': 'absolute_error', 'max_features'...           0.856952
# 5   {'criterion': 'absolute_error', 'max_features'...           0.859854
# 6   {'criterion': 'absolute_error', 'max_features'...           0.857019
# 7   {'criterion': 'absolute_error', 'max_features'...           0.859667
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.854488
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.859503
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.859228
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.858301
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 14  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 15  {'criterion': 'poisson', 'max_features': 'log2...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.778680           0.860845           0.823189
# 1            0.773794           0.860453           0.825942
# 2            0.785448           0.860752           0.826853
# 3            0.783660           0.856915           0.829532
# 4            0.771629           0.859523           0.824388
# 5            0.778278           0.860189           0.828079
# 6            0.772014           0.851602           0.819822
# 7            0.783574           0.861506           0.829128
# 8            0.786488           0.858481           0.823593
# 9            0.779213           0.864647           0.828938
# 10           0.774783           0.862834           0.827143
# 11           0.777365           0.859356           0.824480
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.838542         0.832159        0.030179               10
# 1            0.840174         0.832219        0.032020                9
# 2            0.838668         0.833387        0.026810                7
# 3            0.841372         0.833815        0.027166                3
# 4            0.840982         0.830695        0.032109               11
# 5            0.840849         0.833450        0.030132                5
# 6            0.836140         0.827319        0.030543               12
# 7            0.845153         0.835806        0.028601                1
# 8            0.844038         0.833417        0.026396                6
# 9            0.841505         0.834761        0.030562                2
# 10           0.844174         0.833632        0.032014                4
# 11           0.846658         0.833232        0.030623                8
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14                NaN              NaN             NaN               13
# 15                NaN              NaN             NaN               13

# %%
preinput=scx.transform([[56,75,2,0,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[  1.19567978, 148.99769315,  -4.70207204,  -0.90861367,
#           1.97058663]])

# %%
Future_Prediction=grid.predict(preinput)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[0.84066743]

# %%
preoutput=scy.inverse_transform([Future_Prediction])

# %%
preoutput
# Out:
# array([[23447.1092561]])
