# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","sex_male","bmi","children","smoker_yes"]]

# %%
independent
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
independent=scx.fit_transform(independent)
scy=StandardScaler()
dependent=scy.fit_transform(dependent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features': ['sqrt','log2'],
              'n_estimators':[50,100]}
            
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 20 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 378, in fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.83145413 0.83605136 0.83253552 0.83425891 0.82993203 0.83233471
#  0.83167701 0.83225151 0.83208354 0.83448674 0.83159275 0.83416328
#         nan        nan        nan        nan]
#   warnings.warn(
# C:\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.9766489419636858

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.665986      0.031532         0.020388        0.000798
# 1        1.192859      0.004029         0.036578        0.000799
# 2        0.605224      0.007251         0.020587        0.000800
# 3        1.185663      0.010262         0.036778        0.002038
# 4        1.702544      0.022342         0.018788        0.001166
# 5        3.351523      0.018183         0.035178        0.001165
# 6        1.683357      0.026065         0.018389        0.000490
# 7        3.590774      0.090086         0.040175        0.002991
# 8        0.645798      0.006489         0.020589        0.001020
# 9        1.304190      0.009138         0.039975        0.000894
# 10       0.660989      0.003497         0.020788        0.000747
# 11       1.265614      0.121095         0.039976        0.008289
# 12       0.003397      0.001854         0.000000        0.000000
# 13       0.004596      0.001021         0.000000        0.000000
# 14       0.003997      0.000002         0.000000        0.000000
# 15       0.003399      0.000491         0.000000        0.000000
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4   absolute_error               sqrt                 50
# 5   absolute_error               sqrt                100
# 6   absolute_error               log2                 50
# 7   absolute_error               log2                100
# 8     friedman_mse               sqrt                 50
# 9     friedman_mse               sqrt                100
# 10    friedman_mse               log2                 50
# 11    friedman_mse               log2                100
# 12         poisson               sqrt                 50
# 13         poisson               sqrt                100
# 14         poisson               log2                 50
# 15         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.855200
# 1   {'criterion': 'squared_error', 'max_features':...           0.860314
# 2   {'criterion': 'squared_error', 'max_features':...           0.859119
# 3   {'criterion': 'squared_error', 'max_features':...           0.858028
# 4   {'criterion': 'absolute_error', 'max_features'...           0.853255
# 5   {'criterion': 'absolute_error', 'max_features'...           0.854245
# 6   {'criterion': 'absolute_error', 'max_features'...           0.858381
# 7   {'criterion': 'absolute_error', 'max_features'...           0.859242
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.860051
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.855512
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.855076
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.859088
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 14  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 15  {'criterion': 'poisson', 'max_features': 'log2...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.774747           0.862588           0.827963
# 1            0.786094           0.860460           0.830837
# 2            0.780675           0.859565           0.823141
# 3            0.778189           0.862543           0.832430
# 4            0.778457           0.854598           0.824948
# 5            0.781448           0.857727           0.824542
# 6            0.786123           0.849029           0.822827
# 7            0.770081           0.857988           0.825691
# 8            0.776901           0.856631           0.826452
# 9            0.785045           0.858862           0.830604
# 10           0.774618           0.859199           0.829482
# 11           0.778996           0.860702           0.833146
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.836773         0.831454        0.030949               11
# 1            0.842552         0.836051        0.027385                1
# 2            0.840178         0.832536        0.029235                5
# 3            0.840104         0.834259        0.030154                3
# 4            0.838401         0.829932        0.027924               12
# 5            0.843711         0.832335        0.027944                6
# 6            0.842025         0.831677        0.025592                9
# 7            0.848256         0.832252        0.033332                7
# 8            0.840383         0.832084        0.030101                8
# 9            0.842410         0.834487        0.026678                2
# 10           0.839589         0.831593        0.030424               10
# 11           0.838884         0.834163        0.029639                4
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14                NaN              NaN             NaN               13
# 15                NaN              NaN             NaN               13

# %%
import pickle
finalname="final_rf_model.sav"
pickle.dump(grid,open("final_rf_model.sav",'wb'))

# %%
preinput=scx.transform([[56,75,2,0,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open("final_rf_model.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([0.78649767])

# %%
Future_Prediction=grid.predict(preinput)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[0.78649767]

# %%
preoutput=scy.inverse_transform([Future_Prediction])

# %%
preoutput
# Out:
# array([[22791.3579792]])
