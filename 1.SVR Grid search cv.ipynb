# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","sex_male","bmi","children","smoker_yes"]]

# %%
independent
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.svm import SVR

from sklearn.model_selection import GridSearchCV

param_grid = {'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
              'C': [100,500,1000,2000,3000],
             'gamma':['scale','auto']}

grid = GridSearchCV(SVR(), param_grid, refit = True, verbose= 3,n_jobs=-1)

grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [100, 500, 1000, 2000, 3000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}: 0.8598930084494367

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.121127      0.009819         0.017789        0.002313     100
# 1        0.108732      0.004164         0.021387        0.004920     100
# 2        0.119725      0.005378         0.066959        0.011775     100
# 3        0.118325      0.003825         0.023387        0.001019     100
# 4        0.106336      0.002575         0.016988        0.000893     100
# 5        0.097340      0.002243         0.020788        0.004214     100
# 6        0.118924      0.010014         0.065762        0.012555     100
# 7        0.153104      0.023271         0.031381        0.008931     100
# 8        0.121718      0.007777         0.017390        0.002416     500
# 9        0.150901      0.023682         0.031183        0.016171     500
# 10       0.129117      0.002855         0.059165        0.002783     500
# 11       0.132317      0.008884         0.023186        0.000980     500
# 12       0.121925      0.009269         0.017189        0.001165     500
# 13       0.128717      0.005633         0.020389        0.002056     500
# 14       0.130917      0.003031         0.058365        0.002058     500
# 15       0.132517      0.009324         0.022786        0.000749     500
# 16       0.132916      0.013790         0.023191        0.006968    1000
# 17       0.181683      0.022064         0.026585        0.014793    1000
# 18       0.135515      0.003876         0.058762        0.002558    1000
# 19       0.127119      0.005560         0.022788        0.000749    1000
# 20       0.122524      0.007054         0.017190        0.000746    1000
# 21       0.141910      0.017286         0.018190        0.000748    1000
# 22       0.132916      0.001672         0.058164        0.003124    1000
# 23       0.127918      0.003406         0.022387        0.000491    1000
# 24       0.152900      0.011776         0.016789        0.000979    2000
# 25       0.345383      0.080150         0.031980        0.028984    2000
# 26       0.148907      0.014006         0.059363        0.002059    2000
# 27       0.134316      0.005983         0.023186        0.000978    2000
# 28       0.151104      0.008178         0.017189        0.001469    2000
# 29       0.233854      0.051063         0.017789        0.000748    2000
# 30       0.148909      0.007317         0.058361        0.002650    2000
# 31       0.128519      0.004962         0.023386        0.001496    2000
# 32       0.166491      0.007165         0.016990        0.001788    3000
# 33       0.439326      0.193200         0.018389        0.001019    3000
# 34       0.156501      0.006308         0.058564        0.002869    3000
# 35       0.134914      0.003947         0.025385        0.003553    3000
# 36       0.210868      0.047868         0.032581        0.017433    3000
# 37       0.438127      0.189192         0.018589        0.001623    3000
# 38       0.165497      0.024520         0.065358        0.010568    3000
# 39       0.153904      0.015777         0.037377        0.009346    3000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale         poly
# 2        scale          rbf
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto         poly
# 6         auto          rbf
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale         poly
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto         poly
# 14        auto          rbf
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale         poly
# 18       scale          rbf
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto         poly
# 22        auto          rbf
# 23        auto      sigmoid
# 24       scale       linear
# 25       scale         poly
# 26       scale          rbf
# 27       scale      sigmoid
# 28        auto       linear
# 29        auto         poly
# 30        auto          rbf
# 31        auto      sigmoid
# 32       scale       linear
# 33       scale         poly
# 34       scale          rbf
# 35       scale      sigmoid
# 36        auto       linear
# 37        auto         poly
# 38        auto          rbf
# 39        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 1      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 2       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 3   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 4     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 5       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 8    {'C': 500, 'gamma': 'scale', 'kernel': 'linear'}           0.601152
# 9      {'C': 500, 'gamma': 'scale', 'kernel': 'poly'}           0.780516
# 10      {'C': 500, 'gamma': 'scale', 'kernel': 'rbf'}           0.601802
# 11  {'C': 500, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.466661
# 12    {'C': 500, 'gamma': 'auto', 'kernel': 'linear'}           0.601152
# 13      {'C': 500, 'gamma': 'auto', 'kernel': 'poly'}           0.781613
# 14       {'C': 500, 'gamma': 'auto', 'kernel': 'rbf'}           0.601529
# 15   {'C': 500, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.434785
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.605304
# 17    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.828213
# 18     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.733334
# 19  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.400044
# 20   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.605304
# 21     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.829631
# 22      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.733044
# 23  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.296082
# 24  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.605277
# 25    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.845581
# 26     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.814295
# 27  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.385658
# 28   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.605277
# 29     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.845403
# 30      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.814076
# 31  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.401855
# 32  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.657470
# 33    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.846874
# 34     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.828795
# 35  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.761871
# 36   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.657470
# 37     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.846775
# 38      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.828670
# 39  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.090896
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.655818           0.553380           0.576939
# 1            0.579373           0.471840           0.537966
# 2            0.338741           0.174086           0.217641
# 3            0.563200           0.427152           0.451250
# 4            0.655818           0.553380           0.576939
# 5            0.575051           0.474839           0.535730
# 6            0.339474           0.173708           0.217991
# 7            0.561673           0.428331           0.450454
# 8            0.599729           0.571527           0.542915
# 9            0.780878           0.753634           0.768982
# 10           0.640415           0.534267           0.570844
# 11           0.542011           0.413211           0.459869
# 12           0.599729           0.571527           0.542915
# 13           0.780025           0.754530           0.768597
# 14           0.640750           0.533952           0.571062
# 15           0.549481           0.435040           0.430290
# 16           0.588725           0.623230           0.537931
# 17           0.802622           0.799348           0.800587
# 18           0.745892           0.687037           0.717769
# 19           0.366097           0.242217           0.288461
# 20           0.588725           0.623230           0.537931
# 21           0.802622           0.799620           0.800321
# 22           0.746232           0.686773           0.717920
# 23           0.372281           0.216401           0.291265
# 24           0.583646           0.697368           0.532547
# 25           0.805624           0.816612           0.805133
# 26           0.780971           0.794227           0.793983
# 27          -0.537098          -0.474912          -0.477335
# 28           0.583646           0.697368           0.532547
# 29           0.805639           0.816733           0.805143
# 30           0.781092           0.794081           0.794075
# 31          -0.508082          -0.452827          -0.751013
# 32           0.583501           0.697875           0.529117
# 33           0.805331           0.817283           0.805239
# 34           0.790105           0.811123           0.812857
# 35          -2.139307          -1.704369          -2.340839
# 36           0.583501           0.697875           0.529117
# 37           0.805323           0.817309           0.805191
# 38           0.790265           0.811049           0.812892
# 39          -1.761043          -1.734344          -2.304377
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.546881         0.583498        0.038787               21
# 1            0.424478         0.510155        0.054955               28
# 2            0.183403         0.242982        0.065542               36
# 3            0.432199         0.470546        0.049762               29
# 4            0.546881         0.583498        0.038787               21
# 5            0.424640         0.510181        0.053582               27
# 6            0.183375         0.243024        0.065733               35
# 7            0.431701         0.470105        0.049110               30
# 8            0.565263         0.576117        0.022025               23
# 9            0.687296         0.754261        0.034926               12
# 10           0.521863         0.573838        0.043568               25
# 11           0.428703         0.462091        0.044535               31
# 12           0.565263         0.576117        0.022025               23
# 13           0.687317         0.754417        0.034925               11
# 14           0.521847         0.573828        0.043694               26
# 15           0.425720         0.455063        0.047332               32
# 16           0.616726         0.594383        0.030560               19
# 17           0.735555         0.793265        0.030757                8
# 18           0.649174         0.706641        0.034825               13
# 19           0.351407         0.329645        0.056742               33
# 20           0.616726         0.594383        0.030560               19
# 21           0.735580         0.793555        0.031072                7
# 22           0.649158         0.706625        0.034902               14
# 23           0.351325         0.305471        0.054387               34
# 24           0.681425         0.620053        0.061555               17
# 25           0.754962         0.805582        0.029272                3
# 26           0.733663         0.783428        0.027068                9
# 27          -0.111187        -0.397238        0.150976               37
# 28           0.681425         0.620053        0.061555               17
# 29           0.754961         0.805576        0.029233                4
# 30           0.733656         0.783396        0.027014               10
# 31          -0.111859        -0.445127        0.205197               38
# 32           0.655785         0.624750        0.060379               15
# 33           0.758988         0.806743        0.028307                1
# 34           0.741835         0.796943        0.030174                5
# 35          -1.048739        -1.799025        0.443311               40
# 36           0.655785         0.624750        0.060379               15
# 37           0.758994         0.806718        0.028279                2
# 38           0.741829         0.796941        0.030140                6
# 39          -1.050280        -1.588188        0.469215               39

# %%
preinput=sc.transform([[29,0,36,2,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-0.74766814, -0.97676557,  0.84201193,  0.76341038,  1.98149332]])

# %%
Future_Prediction=grid.predict(preinput)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[36305.57874931]
