# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","sex_male","bmi","children","smoker_yes"]]

# %%
independent
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features': ['sqrt','log2'],
              'n_estimators':[10,100]}
            
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)

grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}: 0.8709854056032609

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.172492      0.042595         0.012193        0.003541
# 1        1.196457      0.031218         0.071756        0.020022
# 2        0.160701      0.033958         0.012192        0.001936
# 3        1.012971      0.024833         0.037577        0.002575
# 4        0.269232      0.020419         0.011193        0.002924
# 5        2.368940      0.213550         0.046025        0.024010
# 6        0.290443      0.049866         0.006596        0.003321
# 7        3.413033      0.445365         0.034377        0.006248
# 8        0.115613      0.012501         0.015629        0.009887
# 9        1.059338      0.077431         0.034374        0.006250
# 10       0.106247      0.011693         0.009374        0.007654
# 11       1.031640      0.032229         0.040624        0.007654
# 12       0.121872      0.006250         0.006249        0.007654
# 13       1.227419      0.204515         0.037499        0.007655
# 14       0.127788      0.022332         0.009374        0.007654
# 15       1.488798      0.171026         0.055707        0.012968
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4   absolute_error               sqrt                 10
# 5   absolute_error               sqrt                100
# 6   absolute_error               log2                 10
# 7   absolute_error               log2                100
# 8     friedman_mse               sqrt                 10
# 9     friedman_mse               sqrt                100
# 10    friedman_mse               log2                 10
# 11    friedman_mse               log2                100
# 12         poisson               sqrt                 10
# 13         poisson               sqrt                100
# 14         poisson               log2                 10
# 15         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.838905
# 1   {'criterion': 'squared_error', 'max_features':...           0.860695
# 2   {'criterion': 'squared_error', 'max_features':...           0.848061
# 3   {'criterion': 'squared_error', 'max_features':...           0.860911
# 4   {'criterion': 'absolute_error', 'max_features'...           0.839528
# 5   {'criterion': 'absolute_error', 'max_features'...           0.857923
# 6   {'criterion': 'absolute_error', 'max_features'...           0.850395
# 7   {'criterion': 'absolute_error', 'max_features'...           0.864725
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.846837
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.860891
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.844294
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.865743
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.841832
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.870315
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.832984
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.860776
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.774883           0.788554           0.810600
# 1            0.786158           0.805571           0.825869
# 2            0.774904           0.777427           0.816425
# 3            0.796140           0.807909           0.820951
# 4            0.783845           0.794393           0.820556
# 5            0.800103           0.806901           0.817319
# 6            0.769082           0.775713           0.805433
# 7            0.797645           0.803589           0.828809
# 8            0.804307           0.799890           0.809328
# 9            0.787569           0.802282           0.827395
# 10           0.758860           0.793303           0.792606
# 11           0.792361           0.805028           0.826754
# 12           0.777982           0.801787           0.807248
# 13           0.794132           0.812004           0.829931
# 14           0.738377           0.774655           0.811411
# 15           0.788517           0.814602           0.834873
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.757951         0.794179        0.028236               12
# 1            0.770017         0.809662        0.031648                7
# 2            0.752726         0.793909        0.033966               13
# 3            0.771373         0.811457        0.029630                5
# 4            0.751495         0.797964        0.030362               10
# 5            0.770340         0.810517        0.028388                6
# 6            0.752381         0.790601        0.034470               14
# 7            0.776219         0.814198        0.030316                3
# 8            0.744712         0.801015        0.032714                9
# 9            0.767800         0.809187        0.032350                8
# 10           0.753935         0.788600        0.032330               15
# 11           0.773611         0.812699        0.031659                4
# 12           0.758414         0.797453        0.028240               11
# 13           0.769577         0.815192        0.034030                1
# 14           0.760454         0.783576        0.034273               16
# 15           0.772717         0.814297        0.031551                2

# %%
preinput=sc.transform([[29,0,36,2,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-0.74766814, -0.97676557,  0.84201193,  0.76341038,  1.98149332]])

# %%
Future_Prediction=grid.predict(preinput)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[38607.1993747]
