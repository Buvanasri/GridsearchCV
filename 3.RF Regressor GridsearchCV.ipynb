# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","sex_male","bmi","children","smoker_yes"]]

# %%
independent
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features': ['sqrt','log2'],
              'n_estimators':[10,100]}
            
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)

grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}: 0.871896975009683

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.118126      0.004164         0.009996        0.001673
# 1        1.346371      0.043544         0.073755        0.012442
# 2        0.162500      0.008350         0.009794        0.001168
# 3        1.317984      0.083611         0.055565        0.007194
# 4        0.268235      0.026166         0.008995        0.000894
# 5        2.559422      0.059819         0.042575        0.007495
# 6        0.286022      0.027373         0.010194        0.002711
# 7        2.590404      0.091501         0.047371        0.015165
# 8        0.131518      0.013024         0.008395        0.000490
# 9        1.213252      0.062402         0.058365        0.019974
# 10       0.208470      0.038387         0.013392        0.004584
# 11       1.258425      0.079600         0.048570        0.004268
# 12       0.136914      0.006352         0.011195        0.005415
# 13       1.432717      0.117092         0.047771        0.005415
# 14       0.151705      0.017815         0.009596        0.000799
# 15       1.233565      0.072736         0.043373        0.009885
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4   absolute_error               sqrt                 10
# 5   absolute_error               sqrt                100
# 6   absolute_error               log2                 10
# 7   absolute_error               log2                100
# 8     friedman_mse               sqrt                 10
# 9     friedman_mse               sqrt                100
# 10    friedman_mse               log2                 10
# 11    friedman_mse               log2                100
# 12         poisson               sqrt                 10
# 13         poisson               sqrt                100
# 14         poisson               log2                 10
# 15         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.876583
# 1   {'criterion': 'squared_error', 'max_features':...           0.859529
# 2   {'criterion': 'squared_error', 'max_features':...           0.823308
# 3   {'criterion': 'squared_error', 'max_features':...           0.861486
# 4   {'criterion': 'absolute_error', 'max_features'...           0.844783
# 5   {'criterion': 'absolute_error', 'max_features'...           0.857966
# 6   {'criterion': 'absolute_error', 'max_features'...           0.842940
# 7   {'criterion': 'absolute_error', 'max_features'...           0.865177
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.837948
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.865010
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.832237
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.860874
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.817935
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.862053
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.823490
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.865999
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.775462           0.793659           0.791654
# 1            0.789772           0.809251           0.830273
# 2            0.758092           0.762992           0.799007
# 3            0.786229           0.807592           0.828082
# 4            0.777710           0.788323           0.814895
# 5            0.790829           0.812312           0.826989
# 6            0.785018           0.782157           0.802374
# 7            0.793073           0.809981           0.823575
# 8            0.758962           0.779120           0.807425
# 9            0.794262           0.811349           0.834591
# 10           0.736760           0.799364           0.799380
# 11           0.793664           0.803779           0.826198
# 12           0.782964           0.783365           0.763802
# 13           0.789596           0.810901           0.826483
# 14           0.756550           0.792063           0.804706
# 15           0.796403           0.810812           0.830356
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.764662         0.800404        0.039560                9
# 1            0.769092         0.811583        0.031416                5
# 2            0.758542         0.780388        0.026328               16
# 3            0.774324         0.811543        0.031015                7
# 4            0.749441         0.795030        0.032537               10
# 5            0.774092         0.812438        0.029058                4
# 6            0.749021         0.792302        0.030643               11
# 7            0.773910         0.813143        0.030882                3
# 8            0.761635         0.789018        0.029947               12
# 9            0.768411         0.814725        0.033161                2
# 10           0.743840         0.782316        0.036414               14
# 11           0.772191         0.811341        0.030254                8
# 12           0.758903         0.781394        0.020770               15
# 13           0.768683         0.811543        0.031917                6
# 14           0.749734         0.785309        0.028186               13
# 15           0.770850         0.814884        0.032091                1

# %%
preinput=sc.transform([[29,36,2,0,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-0.74766814, 71.0431309 , -4.61347681, -0.89833872,  1.98149332]])

# %%
Future_Prediction=grid.predict(preinput)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16579.6859686]
