# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","sex_male","bmi","children","smoker_yes"]]

# %%
independent
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','absolute-error','friedman_mse','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]}
            
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)

grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'friedman_mse', 'absolute_error', 'squared_error'}. Got 'absolute-error' instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}. Got 'absolute-error' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.80495826 0.81149678 0.80748661 0.81151546
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.80413495 0.81028858 0.79029384 0.81264904
#         nan        nan 0.78636996 0.81076668 0.79333615 0.81065413]
#   warnings.warn(
# C:\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute-error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}: 0.8679990204957022

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001999  8.583069e-07         0.000000    0.000000e+00
# 1        0.002197  3.983994e-04         0.000000    0.000000e+00
# 2        0.319439  1.232972e-01         0.008996    2.448183e-03
# 3        1.127032  1.381834e-01         0.038777    2.711038e-03
# 4        0.105535  5.158159e-03         0.008595    4.911090e-04
# 5        0.984633  4.637017e-02         0.037777    9.792190e-04
# 6        0.002399  7.996322e-04         0.000000    0.000000e+00
# 7        0.001799  7.491581e-04         0.000000    0.000000e+00
# 8        0.001997  6.315903e-04         0.000000    0.000000e+00
# 9        0.002597  1.854112e-03         0.000000    0.000000e+00
# 10       0.001599  4.891040e-04         0.000000    0.000000e+00
# 11       0.001199  3.996854e-04         0.000000    0.000000e+00
# 12       0.001799  3.994998e-04         0.000000    0.000000e+00
# 13       0.001998  4.500999e-06         0.000000    0.000000e+00
# 14       0.121244  2.391549e-02         0.008396    4.894733e-04
# 15       0.967804  5.315591e-02         0.036377    1.018898e-03
# 16       0.104335  4.360511e-03         0.007995    3.814697e-07
# 17       0.962208  1.664239e-02         0.036976    1.263577e-03
# 18       0.002000  1.950958e-06         0.000000    0.000000e+00
# 19       0.001399  4.893960e-04         0.000000    0.000000e+00
# 20       0.154304  8.426309e-02         0.008195    4.001618e-04
# 21       1.167880  1.687067e-01         0.037577    1.018421e-02
# 22       0.130520  1.763760e-02         0.012991    7.148901e-03
# 23       1.113313  1.040220e-01         0.038977    1.672030e-03
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute-error               auto                 10
# 7   absolute-error               auto                100
# 8   absolute-error               sqrt                 10
# 9   absolute-error               sqrt                100
# 10  absolute-error               log2                 10
# 11  absolute-error               log2                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               sqrt                 10
# 15    friedman_mse               sqrt                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
# 18         poisson               auto                 10
# 19         poisson               auto                100
# 20         poisson               sqrt                 10
# 21         poisson               sqrt                100
# 22         poisson               log2                 10
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.851097
# 3   {'criterion': 'squared_error', 'max_features':...           0.862644
# 4   {'criterion': 'squared_error', 'max_features':...           0.878234
# 5   {'criterion': 'squared_error', 'max_features':...           0.860587
# 6   {'criterion': 'absolute-error', 'max_features'...                NaN
# 7   {'criterion': 'absolute-error', 'max_features'...                NaN
# 8   {'criterion': 'absolute-error', 'max_features'...                NaN
# 9   {'criterion': 'absolute-error', 'max_features'...                NaN
# 10  {'criterion': 'absolute-error', 'max_features'...                NaN
# 11  {'criterion': 'absolute-error', 'max_features'...                NaN
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.852435
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.859960
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.843563
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.861173
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.834801
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.863353
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.856871
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.861172
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.787136           0.808975           0.809041
# 3            0.789202           0.800436           0.832142
# 4            0.771705           0.802248           0.821270
# 5            0.793030           0.812202           0.819011
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.799385           0.791513           0.809335
# 15           0.792733           0.809626           0.818582
# 16           0.789184           0.753483           0.800035
# 17           0.792778           0.811085           0.826152
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.755502           0.791551           0.811143
# 21           0.788141           0.809430           0.824780
# 22           0.738232           0.792149           0.805834
# 23           0.786722           0.805816           0.830435
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2            0.768544         0.804958        0.027587                8
# 3            0.773060         0.811497        0.032060                3
# 4            0.763977         0.807487        0.040978                7
# 5            0.772746         0.811515        0.029358                2
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8                 NaN              NaN             NaN               13
# 9                 NaN              NaN             NaN               13
# 10                NaN              NaN             NaN               13
# 11                NaN              NaN             NaN               13
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14           0.768006         0.804135        0.027738                9
# 15           0.770542         0.810289        0.029747                6
# 16           0.765204         0.790294        0.031363               11
# 17           0.772057         0.812649        0.030272                1
# 18                NaN              NaN             NaN               13
# 19                NaN              NaN             NaN               13
# 20           0.738853         0.786370        0.035205               12
# 21           0.768129         0.810767        0.032537                4
# 22           0.773594         0.793336        0.039040               10
# 23           0.769126         0.810654        0.032447                5

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("sex male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age:25
# BMI:36
# Children:0
# sex male 0 or 1:1
# Smoker yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[43153.1744603]
