# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","sex_male","bmi","children","smoker_yes"]]

# %%
independent
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute-error','friedman_mse','poisson'],
              'max_features': ['sqrt','log2'],
              'splitter':['best', 'random']}
            
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose=3, n_jobs=-1)

grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 20 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 11 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'absolute_error', 'poisson', 'squared_error', 'friedman_mse'}. Got 'absolute-error' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'squared_error', 'absolute_error', 'friedman_mse', 'poisson'}. Got 'absolute-error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'squared_error', 'poisson', 'friedman_mse', 'absolute_error'}. Got 'absolute-error' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.65037421 0.60986283 0.62334211 0.64427983        nan        nan
#         nan        nan 0.6218149  0.60353953 0.66677134 0.58831758
#  0.61139256 0.62761839 0.67138716 0.56332389]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute-error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}: 0.7257073950678673

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.021987      0.002365         0.007796        0.002039
# 1        0.015592      0.005813         0.007395        0.002576
# 2        0.018186      0.003369         0.013394        0.012870
# 3        0.014391      0.002245         0.007797        0.003249
# 4        0.002198      0.001470         0.000000        0.000000
# 5        0.001600      0.000490         0.000000        0.000000
# 6        0.007394      0.010794         0.000000        0.000000
# 7        0.001399      0.000492         0.000000        0.000000
# 8        0.016390      0.004839         0.007597        0.004713
# 9        0.014991      0.003160         0.008395        0.004452
# 10       0.017390      0.003199         0.006197        0.002399
# 11       0.012193      0.002136         0.005199        0.000398
# 12       0.016990      0.002279         0.005199        0.000401
# 13       0.011590      0.000799         0.005601        0.001360
# 14       0.016789      0.001167         0.004998        0.001095
# 15       0.011992      0.000893         0.005798        0.001720
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4   absolute-error               sqrt           best
# 5   absolute-error               sqrt         random
# 6   absolute-error               log2           best
# 7   absolute-error               log2         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.701652
# 1   {'criterion': 'squared_error', 'max_features':...           0.757116
# 2   {'criterion': 'squared_error', 'max_features':...           0.681703
# 3   {'criterion': 'squared_error', 'max_features':...           0.695475
# 4   {'criterion': 'absolute-error', 'max_features'...                NaN
# 5   {'criterion': 'absolute-error', 'max_features'...                NaN
# 6   {'criterion': 'absolute-error', 'max_features'...                NaN
# 7   {'criterion': 'absolute-error', 'max_features'...                NaN
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.713576
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.673165
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.657754
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.692863
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.741229
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.746038
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.690268
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.629861
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.524881           0.680213           0.699084
# 1            0.529327           0.488097           0.616375
# 2            0.532903           0.696471           0.590646
# 3            0.663670           0.661852           0.656252
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.641574           0.547441           0.538341
# 9            0.436323           0.615433           0.655747
# 10           0.584402           0.770848           0.644049
# 11           0.565020           0.549282           0.585142
# 12           0.452882           0.724413           0.575090
# 13           0.498232           0.614786           0.685659
# 14           0.695912           0.697623           0.624488
# 15           0.607267           0.562367           0.552290
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.646042         0.650374        0.065817                3
# 1            0.658399         0.609863        0.095283                9
# 2            0.614986         0.623342        0.060120                6
# 3            0.544150         0.644280        0.051914                4
# 4                 NaN              NaN             NaN               13
# 5                 NaN              NaN             NaN               13
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8            0.668143         0.621815        0.068493                7
# 9            0.637030         0.603540        0.085788               10
# 10           0.676805         0.666771        0.060523                2
# 11           0.549281         0.588318        0.053908               11
# 12           0.563349         0.611393        0.108058                8
# 13           0.593378         0.627618        0.084226                5
# 14           0.648646         0.671387        0.029540                1
# 15           0.464835         0.563324        0.056887               12

# %%
preinput=sc.transform([[29,36,2,0,1]])
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-0.74766814, 71.0431309 , -4.61347681, -0.89833872,  1.98149332]])

# %%
Future_Prediction=grid.predict(preinput)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[15820.699]
